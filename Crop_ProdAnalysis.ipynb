# %%
import pandas as pd
crop_data = pd.read_csv('/content/cleaned_crop_data.csv')
crop_data.head(90127)
# Out:
#                         State_Name District_Name  Crop_Year       Season  \
# 0      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2      Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4      Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                            ...           ...        ...          ...
# 90122                    Karnataka        HAVERI       2005  Rabi
# 90123                    Karnataka        HAVERI       2005  Rabi
# 90124                    Karnataka        HAVERI       2005  Rabi
# 90125                    Karnataka        HAVERI       2005  Rabi
# 90126                    Karnataka        HAVERI       2005  Rabi
#
#                         Crop    Area  Production
# 0                   Arecanut  1254.0      2000.0
# 1        Other Kharif pulses     2.0         1.0
# 2                       Rice   102.0       321.0
# 3                     Banana   176.0       641.0
# 4                  Cashewnut   720.0       165.0
# ...                      ...     ...         ...
# 90122  Peas & beans (Pulses)     1.0         7.0
# 90123      Rapeseed &Mustard    53.0         8.0
# 90124              Safflower  1888.0      1376.0
# 90125              Sunflower  8059.0      5701.0
# 90126                   Urad   355.0       170.0
#
# [90127 rows x 7 columns]

# %%
crop_data.shape
crop_data.info()
crop_data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161387 entries, 0 to 161386
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     161387 non-null  object
#  1   District_Name  161387 non-null  object
#  2   Crop_Year      161387 non-null  int64
#  3   Season         161387 non-null  object
#  4   Crop           161387 non-null  object
#  5   Area           161387 non-null  float64
#  6   Production     158678 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 8.6+ MB
#            Crop_Year           Area    Production
# count  161387.000000  161387.000000  1.586780e+05
# mean     2005.753592   10598.193549  7.760754e+05
# std         4.935554   34830.227660  2.017939e+07
# min      1997.000000       0.040000  0.000000e+00
# 25%      2002.000000      92.000000  1.000000e+02
# 50%      2006.000000     581.000000  7.100000e+02
# 75%      2010.000000    4074.000000  6.379950e+03
# max      2015.000000  877029.000000  1.125000e+09

# %% [markdown]
# Checking for Missing Values:

# %%
crop_data.isnull().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       2709
# dtype: int64

# %%
crop_data.dtypes
# Out:
# State_Name        object
# District_Name     object
# Crop_Year          int64
# Season            object
# Crop              object
# Area             float64
# Production       float64
# dtype: object

# %%
# Save cleaned data
crop_data.to_csv('cleaned_crop_data.csv', index=False)

# Download the cleaned data
from google.colab import files
files.download('cleaned_crop_data.csv')
